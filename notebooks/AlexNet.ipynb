# %%
import sys
sys.path.append('../')

# %% [markdown]
# **Import Module**

# %%
import torch.nn as nn
from torchvision import models

from models.trainer import Trainer
from datasets.data_manager import DataManager
from models.transform_manager import TransformManager
from models.model_manager import ModelManager
from models.training_manager import TrainingManager
from models.test_manager import TestManager

from results.metrics_visualizer import MetricsVisualizer
from results.metrics_calculator import MetricsCalculator
from results.plot_visualizer import PlotVisualizer
from results.heatmap_generator import HeatmapGenerator

# %% [markdown]
# **Define Model Class**

# %%
class AlexNetMultiLabel(nn.Module):

    def __init__(self, num_classes):
        super(AlexNetMultiLabel, self).__init__()
        self.model = models.alexnet(pretrained=True)
        self.model.classifier[6] = nn.Linear(4096, num_classes)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# **Define Model Name & Initialize Model Class**

# %%
modelName = "AlexNet"
MODEL = AlexNetMultiLabel

# %% [markdown]
# **Constants**

# %%
BATCH_SIZE =64
LEARNING_RATE = 1e-4
SIZE = 224
FOLD_SPLITS=2
EPOCHS = 30
DEVICE = "cuda"

MAIN_CSV_FILE = "../final_label.csv"
LABEL_COLS = ["Fracture", "CalvarialFracture", "OtherFracture"]
DATASET_PATH = "../Dataset_PNG"
TEST_CSV_FILE = "../test_fold.csv"

MODEL_SAVE_PATH = f"./models/{modelName}"
TRAINING_VALIDATION_PLOT_SAVE_PATH = f"./results/{modelName}"
PLOT_SAVE_PATH = f"./results/{modelName}"
GRADCAM_HEATMAP_SAVE_PATH = f"./results/{modelName}"
CAM_OUTPUT_SIZE = 512

# %% [markdown]
# ***Initialize necessary modules***

# %%
data_manager = DataManager(MAIN_CSV_FILE, LABEL_COLS, FOLD_SPLITS)

transform_manager = TransformManager(DATASET_PATH, SIZE, BATCH_SIZE)

model_manager = ModelManager(LABEL_COLS, DEVICE, MODEL_SAVE_PATH, MODEL, LEARNING_RATE)

training_manager = TrainingManager(data_manager, transform_manager, model_manager, EPOCHS)

# %% [markdown]
# ***Begin training***

# %%
training_manager.run_training()
# Out:
# Processing Folds:   0%|          | 0/2 [00:00<?, ?it/s]
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 1/30 - Train Loss: 40.0455, Train Accuracy: 0.7284, Val Loss: 45.0981, Val Accuracy: 0.7166
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 2/30 - Train Loss: 32.0039, Train Accuracy: 0.8080, Val Loss: 26.3013, Val Accuracy: 0.8646
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 3/30 - Train Loss: 26.2484, Train Accuracy: 0.8490, Val Loss: 36.8473, Val Accuracy: 0.7960
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 4/30 - Train Loss: 23.0319, Train Accuracy: 0.8713, Val Loss: 18.5893, Val Accuracy: 0.9034
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 5/30 - Train Loss: 20.0641, Train Accuracy: 0.8881, Val Loss: 37.9800, Val Accuracy: 0.7999
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 6/30 - Train Loss: 21.9750, Train Accuracy: 0.8762, Val Loss: 13.9386, Val Accuracy: 0.9305
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 7/30 - Train Loss: 16.7252, Train Accuracy: 0.9100, Val Loss: 12.8919, Val Accuracy: 0.9304
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 8/30 - Train Loss: 15.3964, Train Accuracy: 0.9187, Val Loss: 12.2996, Val Accuracy: 0.9410
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 9/30 - Train Loss: 13.6315, Train Accuracy: 0.9293, Val Loss: 13.0281, Val Accuracy: 0.9289
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 10/30 - Train Loss: 12.3879, Train Accuracy: 0.9360, Val Loss: 12.2334, Val Accuracy: 0.9391
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 9/30 - Train Loss: 14.1877, Train Accuracy: 0.9271, Val Loss: 10.5022, Val Accuracy: 0.9527
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 10/30 - Train Loss: 11.9761, Train Accuracy: 0.9356, Val Loss: 23.6643, Val Accuracy: 0.9007
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 11/30 - Train Loss: 11.8015, Train Accuracy: 0.9418, Val Loss: 9.2820, Val Accuracy: 0.9530
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 12/30 - Train Loss: 10.5398, Train Accuracy: 0.9468, Val Loss: 10.6115, Val Accuracy: 0.9470
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 13/30 - Train Loss: 10.9209, Train Accuracy: 0.9438, Val Loss: 9.4670, Val Accuracy: 0.9532
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 14/30 - Train Loss: 9.5294, Train Accuracy: 0.9536, Val Loss: 17.8168, Val Accuracy: 0.9095
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 15/30 - Train Loss: 11.6421, Train Accuracy: 0.9426, Val Loss: 6.2578, Val Accuracy: 0.9695
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 16/30 - Train Loss: 8.5668, Train Accuracy: 0.9598, Val Loss: 4.9473, Val Accuracy: 0.9771
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 17/30 - Train Loss: 8.0901, Train Accuracy: 0.9597, Val Loss: 5.8174, Val Accuracy: 0.9736
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 18/30 - Train Loss: 9.4737, Train Accuracy: 0.9529, Val Loss: 6.5365, Val Accuracy: 0.9693
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 19/30 - Train Loss: 7.1355, Train Accuracy: 0.9645, Val Loss: 6.0903, Val Accuracy: 0.9716
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 20/30 - Train Loss: 7.7481, Train Accuracy: 0.9607, Val Loss: 8.8278, Val Accuracy: 0.9531
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 21/30 - Train Loss: 7.0599, Train Accuracy: 0.9651, Val Loss: 4.1787, Val Accuracy: 0.9824
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 22/30 - Train Loss: 7.7272, Train Accuracy: 0.9618, Val Loss: 4.1507, Val Accuracy: 0.9811
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 23/30 - Train Loss: 5.5229, Train Accuracy: 0.9709, Val Loss: 4.1980, Val Accuracy: 0.9786
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 24/30 - Train Loss: 5.0742, Train Accuracy: 0.9757, Val Loss: 3.8786, Val Accuracy: 0.9829
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 25/30 - Train Loss: 6.5822, Train Accuracy: 0.9685, Val Loss: 3.2505, Val Accuracy: 0.9885
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 26/30 - Train Loss: 5.7114, Train Accuracy: 0.9716, Val Loss: 7.6426, Val Accuracy: 0.9628
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 27/30 - Train Loss: 4.1680, Train Accuracy: 0.9790, Val Loss: 6.1642, Val Accuracy: 0.9724
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 28/30 - Train Loss: 4.9284, Train Accuracy: 0.9754, Val Loss: 5.7208, Val Accuracy: 0.9732
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 29/30 - Train Loss: 4.5026, Train Accuracy: 0.9774, Val Loss: 5.9714, Val Accuracy: 0.9729
# Processing Training Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Processing Validation Folds:   0%|          | 0/78 [00:00<?, ?it/s]
# Epoch 30/30 - Train Loss: 5.4399, Train Accuracy: 0.9747, Val Loss: 3.1810, Val Accuracy: 0.9875

# %% [markdown]
# ***Show Training vs Validation Plot***

# %%
visualizer = MetricsVisualizer(training_manager.train_losses, training_manager.val_losses, training_manager.train_accuracies, training_manager.val_accuracies, TRAINING_VALIDATION_PLOT_SAVE_PATH)
visualizer.plot_metrics()

# %%
# # Sample reload example


# import results.metrics_visualizer
# import importlib
# importlib.reload(results.metrics_visualizer)
# from results.metrics_visualizer import MetricsVisualizer
# visualizer = MetricsVisualizer(training_manager.train_losses, training_manager.val_losses, training_manager.train_accuracies, training_manager.val_accuracies, TRAINING_VALIDATION_PLOT_SAVE_PATH)
# visualizer.plot_metrics()

# %% [markdown]
# ***Begin Inference***

# %%
model_predictor = TestManager(DATASET_PATH, TEST_CSV_FILE, LABEL_COLS, SIZE, MODEL, DEVICE, MODEL_SAVE_PATH, FOLD_SPLITS)

predictions, true_labels, probabilities = model_predictor.make_predictions()
# Out:
# Processing Folds:   0%|          | 0/2 [00:00<?, ?it/s]
# Processing Prediction:   0%|          | 0/2468 [00:00<?, ?it/s]
# Processing Prediction:   0%|          | 0/2468 [00:00<?, ?it/s]

# %% [markdown]
# ***Compute and Display Metrics***

# %%
metrics_calculator = MetricsCalculator(LABEL_COLS)

aggregated_metrics, metrics_per_class, classification_reports, multi_label_report = metrics_calculator.compute_metrics(predictions[0], true_labels[0])
metrics_calculator.display_metrics(aggregated_metrics, metrics_per_class, classification_reports, multi_label_report)
# Out:
# Aggregated Metrics:
# {'accuracy': 0.9648838465694219, 'f1_score': 0.9411249148161911, 'specificity': 0.9958597068919542, 'sensitivity': 0.9033076742130071}
#
# Class-wise Metrics:
#
# Fracture:
# {'accuracy': 0.9615072933549432, 'f1_score': 0.9531789058649581, 'specificity': 1.0, 'sensitivity': 0.9105461393596986}
#
# CalvarialFracture:
# {'accuracy': 0.9606969205834684, 'f1_score': 0.9478214093598708, 'specificity': 0.9979906229068989, 'sensitivity': 0.9035897435897436}
#
# OtherFracture:
# {'accuracy': 0.9724473257698542, 'f1_score': 0.9223744292237442, 'specificity': 0.9895884977689638, 'sensitivity': 0.8957871396895787}
#
# Classification Reports Per Class:
#
# Fracture:
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97      1406
#          1.0       1.00      0.91      0.95      1062
#
#     accuracy                           0.96      2468
#    macro avg       0.97      0.96      0.96      2468
# weighted avg       0.96      0.96      0.96      2468
#
#
# CalvarialFracture:
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97      1493
#          1.0       1.00      0.90      0.95       975
#
#     accuracy                           0.96      2468
#    macro avg       0.97      0.95      0.96      2468
# weighted avg       0.96      0.96      0.96      2468
#
#
# OtherFracture:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.98      2017
#          1.0       0.95      0.90      0.92       451
#
#     accuracy                           0.97      2468
#    macro avg       0.96      0.94      0.95      2468
# weighted avg       0.97      0.97      0.97      2468
#
#
# Multi-label Classification Reports:
#                    precision    recall  f1-score   support
#
#          Fracture       1.00      0.91      0.95      1062
# CalvarialFracture       1.00      0.90      0.95       975
#     OtherFracture       0.95      0.90      0.92       451
#
#         micro avg       0.99      0.91      0.95      2488
#         macro avg       0.98      0.90      0.94      2488
#      weighted avg       0.99      0.91      0.95      2488
#       samples avg       1.00      0.96      0.96      2488

# %% [markdown]
# ***Display Plots***

# %%
plot_visualizer = PlotVisualizer(LABEL_COLS, PLOT_SAVE_PATH)
plot_visualizer.plot_multilabel_confusion_matrix(true_labels, predictions)
plot_visualizer.plot_roc_curve(true_labels, probabilities)
plot_visualizer.plot_precision_recall_curve(true_labels, probabilities)

# %% [markdown]
# ***GRADCAM HeatMap Generation***

# %%
generator = HeatmapGenerator(model_predictor, TEST_CSV_FILE, MODEL, SIZE, DATASET_PATH, CAM_OUTPUT_SIZE, GRADCAM_HEATMAP_SAVE_PATH)

generator.plot_heatmaps()
